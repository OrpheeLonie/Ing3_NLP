# %% [markdown]
# # Theorical Questions

# %% [markdown]
# ### Question 1 : Explain with your own words, using a short paragraph for each, what are:
#
#     Phonetics and phonology :
# La phonologie est le domaine qui étudie l'agencement des sons dans des langages. La phonétique se focalise sur l'action physique qui produit un son.
#
#     Morphology and syntax :
# La morphologie étudie la formation d'un mot, avec les préfix ou suffix par exemple, tandis que la syntax regarde la formation des mots au sein d'une phrase.
#
#     Semantics and pragmatics :
# Une élément sémantique recherche la signification d'un mot. Etre pragmatique recherche une signification plus humaine.

# %% [markdown]
# #### Question 2 : What is the difference between stemming and lemmatization?
#
# Stemming analyse the morphology of the word when Lemmatization will focus on studying the meaning of the word.
#
#     How do they both work?
# Stemming consists of cutting and deleting the suffix of the given words to retrieve the stem of the words.
# Lemmatization will study the morphology of the words in a sentence and compare with a dictionnary.
#
#     What are the pros and cons of both methods?
# Both of them are efficient the positive point of Lemmatization is that it really evaluate the meaning of each words.

# %% [markdown]
# #### Question 3 : On logistic regression:
#
#     How does stochastic gradient descent work?
# Stochastic gradient descent or SGD choose an initial vector with a learning rate and try to minimize the loss function. It chooses a training example per epoch to improves the parameters.
#
#     What is the role of the learning rate?
# The learning rate is consider as an hyperparameter
#
#     Will it always find the global minimum?
# It will not always ind the global minimum

# %% [markdown]
# #### Question 4 : What problems does TF-iDF try to solve?
# It permits to evaluate the value of a word in a document, considering a collection. As the word is present in the document its weight grows.
#
#     What the is the TF part for?
# Term frequency : the frequency a word will appear in a document
#
#     What is the iDF part for?
# Inverse Document Frequency : the non frequency of a word, means the word is more unusual.

# %% [markdown]
# #### Question 5 : Summarize how the skip-gram method of Word2Vec works using a couple of paragraphs.
# The sentence is divide by words and each word will be evaluate by the model. Skip Gram will predict the context by getting into a projection and output a sentence with the word given in input.
#
#     How does it uses the fact that two words appearing in similar contexts are likely to have similar meanings?
# The model will associate words that are close to the given word in input as similar and radom other words as negative.

# %% [markdown]
# #### Question 6 : What are the differences between an RNN and an LSTM?
# RNN means Recurrent Neural Network and LSTM Long short-term memory. RNN have reccurent connections.
#
#     What problem is an LSTM trying to solve compared to a basic RNN?
# LSTM are more effective than RNN, because RNN couldn't solve vanishing gradient problem.

# %% [markdown]
# #### Question 7 : What would you expect if we use one of our classifiers trained on IMDB on Twitter data, and why?
